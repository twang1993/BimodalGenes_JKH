# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dir1 = 'optimum parameter in randomforest/'
plt.figure(figsize=(24,7))
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 7
for ii in range(9):
    for jj in range(3):
        if jj==0:
            if ii==0:
                df=pd.read_csv(dir1+'(Test) optimum parameter of LiverCirrhosis in random forest(11_genes).csv')
            if ii==1:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_Carcinoma in random forest(11_genes).csv')
            if ii==2:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Obesity in random forest(11_genes).csv')
            if ii==3:
                df=pd.read_csv(dir1+'(Test) optimum parameter of CrohnsDisease in random forest(11_genes).csv')
            if ii==4:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_AdvancedAdenoma in random forest(11_genes).csv')
            if ii==5:
                df=pd.read_csv(dir1+'(Test) optimum parameter of UlcerativeColitis in random forest(11_genes).csv')
            if ii==6:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Type2Diabetes in random forest(11_genes).csv')
            if ii==7:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_Moderate in random forest(11_genes).csv')
            if ii==8:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_High in random forest(11_genes).csv')
        if jj==1:
            if ii==0:
                df=pd.read_csv(dir1+'(Test) optimum parameter of LiverCirrhosis in random forest(41_genes).csv')
            if ii==1:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_Carcinoma in random forest(41_genes).csv')
            if ii==2:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Obesity in random forest(41_genes).csv')
            if ii==3:
                df=pd.read_csv(dir1+'(Test) optimum parameter of CrohnsDisease in random forest(41_genes).csv')
            if ii==4:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_AdvancedAdenoma in random forest(41_genes).csv')
            if ii==5:
                df=pd.read_csv(dir1+'(Test) optimum parameter of UlcerativeColitis in random forest(41_genes).csv')
            if ii==6:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Type2Diabetes in random forest(41_genes).csv')
            if ii==7:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_Moderate in random forest(41_genes).csv')
            if ii==8:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_High in random forest(41_genes).csv')
        if jj==2:
            if ii==0:
                df=pd.read_csv(dir1+'(Test) optimum parameter of LiverCirrhosis in random forest(all_genes).csv')
            if ii==1:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_Carcinoma in random forest(all_genes).csv')
            if ii==2:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Obesity in random forest(all_genes).csv')
            if ii==3:
                df=pd.read_csv(dir1+'(Test) optimum parameter of CrohnsDisease in random forest(all_genes).csv')
            if ii==4:
                df=pd.read_csv(dir1+'(Test) optimum parameter of ColorectalCancer_AdvancedAdenoma in random forest(all_genes).csv')
            if ii==5:
                df=pd.read_csv(dir1+'(Test) optimum parameter of UlcerativeColitis in random forest(all_genes).csv')
            if ii==6:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Type2Diabetes in random forest(all_genes).csv')
            if ii==7:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_Moderate in random forest(all_genes).csv')
            if ii==8:
                df=pd.read_csv(dir1+'(Test) optimum parameter of Arthritis_High in random forest(all_genes).csv')
        TreeNumberMax=np.size(df,0)
        XX=np.arange(1,TreeNumberMax+1,1)
        Index=np.arange(0,50,2)
        MM=np.zeros(TreeNumberMax)
        EE=np.zeros(TreeNumberMax)
        for i in range(TreeNumberMax):
            MM[i]=np.mean(df.iloc[i,1:])
            EE[i]=np.std(df.iloc[i,1:])
        plt.subplot(3,9,jj*9+ii+1)
        plt.errorbar(XX[Index], MM[Index], yerr=EE[Index], fmt='o-', color="#8A8AFF",fillstyle='none')
        plt.tick_params(axis='both', which='major', labelsize=8)
        plt.subplot(3,9,1)
        plt.title('Liver cirrhosis',fontsize=10)
        plt.subplot(3,9,2)
        plt.title('Colorectal cancer carcinoma',fontsize=10)
        plt.subplot(3,9,3)
        plt.title('Obesity',fontsize=10)
        plt.subplot(3,9,4)
        plt.title("Crohn's disease",fontsize=10)
        plt.subplot(3,9,5)
        plt.title('Colorectal cancer advanced adenoma',fontsize=10)
        plt.subplot(3,9,6)
        plt.title('Ulcerative colitis',fontsize=10)
        plt.subplot(3,9,7)
        plt.title('Type 2 diabetes',fontsize=10)
        plt.subplot(3,9,8)
        plt.title('Arthritis moderate',fontsize=10)
        plt.subplot(3,9,9)
        plt.title('Arthritis high',fontsize=10)

    plt.subplot(3,9,19)
    plt.xlabel('Number of decision trees',fontsize=10)
    plt.ylabel('AUC',fontsize=10)
plt.savefig('fig/AUC_versus_TreeNumber.pdf',bbox_inches='tight')
